# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import datetime
from dateutil.relativedelta import relativedelta

# %%
P_domestic_weekday = pd.read_csv('NO SC DOMESTIC WEEKDAY.csv')
P_domestic_weekend = pd.read_csv('NO SC DOMESTIC WEEKEND.csv')
P_park_and_ride_weekday = pd.read_csv('NO SC PARK AND RIDE WEEKDAY.csv')
P_park_and_ride_weekend = pd.read_csv(' NO SC PARK AND RIDE WEEKEND.csv')
P_science_park_weekday = pd.read_csv('NO SC SCIENCE PARK WEEKDAY.csv')

# %%
Power_weekday = np.zeros(len(P_domestic_weekday))
Power_weekend = np.zeros(len(P_domestic_weekday))
for i in range(len(P_domestic_weekday)):
    Power_weekday[i] = P_domestic_weekday.iloc[i][1] + P_park_and_ride_weekday.iloc[i][1] + P_science_park_weekday.iloc[i][1]
    Power_weekend[i] = P_domestic_weekend.iloc[i][1] + P_park_and_ride_weekend.iloc[i][1]

# %%
plt.plot(Power_weekday)
plt.ylabel('Power(kW)')
plt.xticks(np.arange(0,17280,1440),('Jan','Feb','March','April','May','June','July','Aug','Sept','Oct','Nov','Dec'))
plt.grid()

# %%
plt.plot(Power_weekend)
plt.ylabel('Power(kW)')
plt.xticks(np.arange(0,17280,1440),('Jan','Feb','March','April','May','June','July','Aug','Sept','Oct','Nov','Dec'))
plt.grid()

# %%
Feb_weekday = Power_weekday[2880:4320]
Feb_weekend = Power_weekend[2880:4320]
Aug_weekday = Power_weekday[11520:12960]
Aug_weekend = Power_weekend[11520:12960]

# %%
dfC = pd.read_csv("data/sspsbpniv.csv")
dfC.head()

MONTH= np.zeros(len(dfC))
for i in range(len(dfC)):
    MONTH[i] = datetime.datetime.strptime(dfC['Date'].iloc[i], '%d/%m/%Y').date().month

dfC['Month'] = MONTH
month = 2
dfc = dfC[dfC['Month'].eq(month)]

Cost = np.zeros(48)
for i in range(1,49,1):
    dfc1 = dfc[dfc['HalfHour'].eq(i)]
    Cost[i-1] = np.mean(dfc1['import(VAT)'].iloc[:])
cost = np.zeros(1440)

for i in range(len(Cost)):
    cost[(30*(i-1))+30:(30*i)+30] = Cost[i]
        
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time of the day (hours)')
plt.xticks(np.arange(0,1440,180),('00:00','03:00','06:00','09:00','12:00','15:00','18:00','21:00','24:00'))
ax1.set_ylabel('Power(kW)', color=color)
plt.ylim(0,2000)
ax1.plot(Feb_weekday, color=color)
plt.grid()
ax1.tick_params(axis='y', labelcolor=color)


ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Price per kWh(£)', color=color)  
plt.ylim(0,0.40)
ax2.plot(cost, color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.grid()
plt.show()

# %%
dfC = pd.read_csv("data/sspsbpniv.csv")
dfC.head()

MONTH= np.zeros(len(dfC))
for i in range(len(dfC)):
    MONTH[i] = datetime.datetime.strptime(dfC['Date'].iloc[i], '%d/%m/%Y').date().month

dfC['Month'] = MONTH
month = 2
dfc = dfC[dfC['Month'].eq(month)]

Cost = np.zeros(48)
for i in range(1,49,1):
    dfc1 = dfc[dfc['HalfHour'].eq(i)]
    Cost[i-1] = np.mean(dfc1['import(VAT)'].iloc[:])
cost = np.zeros(1440)

for i in range(len(Cost)):
    cost[(30*(i-1))+30:(30*i)+30] = Cost[i]
        
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time of the day (hours)')
plt.xticks(np.arange(0,1440,180),('00:00','03:00','06:00','09:00','12:00','15:00','18:00','21:00','24:00'))
ax1.set_ylabel('Power(kW)', color=color)
plt.ylim(0,1000)
ax1.plot(Feb_weekend, color=color)
plt.grid()
ax1.tick_params(axis='y', labelcolor=color)


ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Price per kWh(£)', color=color)  
plt.ylim(0,0.50)
ax2.plot(cost, color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.grid()
plt.show()

# %%
dfC = pd.read_csv("data/sspsbpniv.csv")
dfC.head()

MONTH= np.zeros(len(dfC))
for i in range(len(dfC)):
    MONTH[i] = datetime.datetime.strptime(dfC['Date'].iloc[i], '%d/%m/%Y').date().month

dfC['Month'] = MONTH
month = 8
dfc = dfC[dfC['Month'].eq(month)]

Cost = np.zeros(48)
for i in range(1,49,1):
    dfc1 = dfc[dfc['HalfHour'].eq(i)]
    Cost[i-1] = np.mean(dfc1['import(VAT)'].iloc[:])
cost = np.zeros(1440)

for i in range(len(Cost)):
    cost[(30*(i-1))+30:(30*i)+30] = Cost[i]
        
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time of the day (hours)')
plt.xticks(np.arange(0,1440,180),('00:00','03:00','06:00','09:00','12:00','15:00','18:00','21:00','24:00'))
ax1.set_ylabel('Power(kW)', color=color)
plt.ylim(0,2500)
ax1.plot(Aug_weekday, color=color)
plt.grid()
ax1.tick_params(axis='y', labelcolor=color)


ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Price per kWh(£)', color=color)  
plt.ylim(0,0.50)
ax2.plot(cost, color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.grid()
plt.show()

# %%
dfC = pd.read_csv("data/sspsbpniv.csv")
dfC.head()

MONTH= np.zeros(len(dfC))
for i in range(len(dfC)):
    MONTH[i] = datetime.datetime.strptime(dfC['Date'].iloc[i], '%d/%m/%Y').date().month

dfC['Month'] = MONTH
month = 8
dfc = dfC[dfC['Month'].eq(month)]

Cost = np.zeros(48)
for i in range(1,49,1):
    dfc1 = dfc[dfc['HalfHour'].eq(i)]
    Cost[i-1] = np.mean(dfc1['import(VAT)'].iloc[:])
cost = np.zeros(1440)

for i in range(len(Cost)):
    cost[(30*(i-1))+30:(30*i)+30] = Cost[i]
        
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time of the day (hours)')
plt.xticks(np.arange(0,1440,180),('00:00','03:00','06:00','09:00','12:00','15:00','18:00','21:00','24:00'))
ax1.set_ylabel('Power(kW)', color=color)
plt.ylim(0,1000)
ax1.plot(Aug_weekend, color=color)
plt.grid()
ax1.tick_params(axis='y', labelcolor=color)


ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Price per kWh(£)', color=color)  
plt.ylim(0,0.50)
ax2.plot(cost, color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.grid()
plt.show()

# %%
Total_cost_weekday = np.zeros(12)
for Z in range(12):
    dfC = pd.read_csv("data/sspsbpniv.csv")

    MONTH = np.zeros(len(dfC))
    for i in range(len(dfC)):
        MONTH[i] = datetime.datetime.strptime(dfC['Date'].iloc[i], '%d/%m/%Y').date().month

    dfC['Month'] = MONTH
    month = Z+1
    dfc = dfC[dfC['Month'].eq(month)]

    Cost = np.zeros(48)
    for i in range(1,49,1):
        dfc1 = dfc[dfc['HalfHour'].eq(i)]
        Cost[i-1] = np.mean(dfc1['import(VAT)'].iloc[:])
    cost = np.zeros(1440)

    for i in range(len(Cost)):
        cost[(30*(i-1))+30:(30*i)+30] = Cost[i]
        
    Energy = Power_weekday[Z*1440:(Z+1)*1440]/60
    
    Total_cost_weekday[Z] = np.sum(Energy*cost)

# %%
Total_cost_weekend = np.zeros(12)
for Z in range(12):
    dfC = pd.read_csv("data/sspsbpniv.csv")

    MONTH = np.zeros(len(dfC))
    for i in range(len(dfC)):
        MONTH[i] = datetime.datetime.strptime(dfC['Date'].iloc[i], '%d/%m/%Y').date().month

    dfC['Month'] = MONTH
    month = Z+1
    dfc = dfC[dfC['Month'].eq(month)]

    Cost = np.zeros(48)
    for i in range(1,49,1):
        dfc1 = dfc[dfc['HalfHour'].eq(i)]
        Cost[i-1] = np.mean(dfc1['import(VAT)'].iloc[:])
    cost = np.zeros(1440)

    for i in range(len(Cost)):
        cost[(30*(i-1))+30:(30*i)+30] = Cost[i]
        
    Energy = Power_weekend[Z*1440:(Z+1)*1440]/60
    
    Total_cost_weekend[Z] = np.sum(Energy*cost)

# %%
DF = pd.DataFrame(Total_cost_weekday)

DF.to_csv('NO SC TOTAL WEEKDAY COST.csv')

# %%
DF1 = pd.DataFrame(Total_cost_weekend)

DF1.to_csv('NO SC TOTAL WEEKEND COST.csv')
